# %%
import matplotlib.pyplot as plt

# %%
mean = [0.737164329, 0.721675961, 0.740246874, 0.096821739, 0.741667531, 0.711385322]
std = [0.033685636, 0.09821265, 0.049752427, 0.032376347, 0.070475664, 0.121619895]
label = ['Combo 19', 'Combo 20', 'Combo 22', 'Combo 27', 'Combo 30', 'Combo 42']

# %%
plt.figure(figsize=(12, 8), dpi=100)
plt.errorbar(label, mean, std, linestyle='-', marker='^',color = 'blue')
plt.title('Synergistic Effects Observed in the 2nd Round Experiment', fontsize = 16)
plt.xticks(label, fontsize= 10)
plt.yticks(fontsize= 13)
plt.show()

# %%
# 19	1.00	0.5000	3200.00	64	0.737
# 20	16.00	32.0000	200.00	1	0.722
# 22	16.00	4.0000	100.00	0	0.740
# 27	8.00	0.1250	1600.00	1	0.097
# 30	128.00	0.0000	25.00	8	0.742
# 42	0.50	0.0000	1600.00	8	0.711
