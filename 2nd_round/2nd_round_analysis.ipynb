# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2nd

# %%
init = pd.read_csv('1st_round.txt', sep = ',')

# %%
y_init = pd.read_csv('2nd_final.csv', header = None)

# %%
y_init[y_init > 1] = 1

# %%
y_init
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.973660  0.878416  0.913125  0.935773  0.821536  0.848115  0.884904
# 1  1.000000  0.931576  0.907981  0.848835  0.782858  0.744297  0.754404
# 2  0.771508  0.737164  0.721676  0.758443  0.740247  0.718285  0.798064
# 3  0.096822  0.890986  0.894696  0.741668  0.778921  0.760397  0.797300
# 4  0.910967  0.914195  0.841744  0.773689  0.797484  0.762029  0.711385
# 5  0.867699  0.924997  1.000000  0.970751  1.000000  0.878557  0.741614
#
#           7         8
# 0  0.774647  0.903825
# 1  0.806809  0.847043
# 2  0.787027  0.887375
# 3  0.793585  0.771066
# 4  0.959538  1.000000
# 5  0.754740  1.000000

# %%
y_init = y_init.values

# %%
y_init = y_init.reshape(-1)

# %%
y_init = np.round(y_init, 3)

# %%
init['Cell viability'] = y_init

# %%
init
# Out:
#     (+)-Griseofulvin  (S)-(+)-Camptothecin  Chloramphenicol  Metformin  \
# 0               4.00                4.0000          1600.00         32
# 1               0.25                4.0000             6.25          0
# 2               2.00                4.0000            50.00          0
# 3               2.00               16.0000           400.00        256
# 4               0.00                0.1250           200.00          1
# 5               8.00                0.2500           400.00          8
# 6               2.00                0.5000          1600.00          4
# 7               0.25                1.0000           400.00        512
# 8              64.00                2.0000           200.00          1
# 9               0.50                0.0000          1600.00          1
# 10              0.25                1.0000             0.00          4
# 11              1.00                4.0000            12.50        512
# ...

# %%
init.to_csv("2nd_final.txt", header=True, index=None, sep=',', mode='w')
